# %%
import pandas as pd
import numpy as np

# %% [markdown]
# MUHAMMAD FAIZAN RAFIQ 2303.005.DEG.KHI
# MUHAMMAD HUZAIFA WASSEEM 2303-KHI-DEG-021
# HAMMAD IRSHAD 2303.KHI.DEG.032

# %%
df1 = pd.read_parquet("/home/muhammadfaizanrafique/data_engineering_bootcamp_2303/tasks/5_data_pipelines/day_4_data_lake/data/output_data/employee_earnings/earnings_date=2022-02-10/employee_earnings.parquet")
df1
# Out:
#     emp_id first_name middle_initial last_name                         email  \
# 0   526540  Angelique              K   Goodwin   angelique.goodwin@gmail.com
# 1   859327       Jeni              S   Shaffer        jeni.shaffer@gmail.com
# 2   887387     Donald              T    Farris   donald.farris@bellsouth.net
# 3   779497     Steven              D    Rendon       steven.rendon@gmail.com
# 4   896517     Jenell              L   Almanza      jenell.almanza@yahoo.com
# ..     ...        ...            ...       ...                           ...
# 95  549389   Clemente              M     Gould    clemente.gould@hotmail.com
# 96  466832      Chang              K     Roden         chang.roden@yahoo.com
# 97  203380     Marvin              R    Nickel         marvin.nickel@ibm.com
# 98  915991     Eldora              Y   Tribble  eldora.tribble@earthlink.net
# 99  289172      Azzie              L    Layman    azzie.layman@hotmail.co.uk
#
# ...

# %%
random_numbers = np.random.randint(10000, 100000, size=len(df1))

# %%
df1.iloc[:,-1:] = random_numbers

# %%
new_earning_col = df1.loc[:,"earnings"]
new_earning_col
# Out:
# 0     19982
# 1     35859
# 2     32109
# 3     55647
# 4     54240
#       ...
# 95    45419
# 96    76891
# 97    96184
# 98    61389
# 99    30616
# Name: earnings, Length: 100, dtype: int64

# %%
df1.head()
# Out:
#    emp_id first_name middle_initial last_name                        email  \
# 0  526540  Angelique              K   Goodwin  angelique.goodwin@gmail.com
# 1  859327       Jeni              S   Shaffer       jeni.shaffer@gmail.com
# 2  887387     Donald              T    Farris  donald.farris@bellsouth.net
# 3  779497     Steven              D    Rendon      steven.rendon@gmail.com
# 4  896517     Jenell              L   Almanza     jenell.almanza@yahoo.com
#
#   date_of_birth date_of_joining          ssn  phone_number  user_name  \
# 0    1964-05-15      2001-03-24  471-57-0359  212-884-7146  akgoodwin
# 1    1962-01-13      2015-12-10  624-85-4146  205-665-7020  jsshaffer
# 2    1958-04-11      1979-11-12  097-02-3315  205-959-7879   dtfarris
# 3    1982-04-04      2008-09-18  134-98-6566  217-858-0054   sdrendon
# 4    1958-07-01      1993-07-14  599-92-7345  314-893-2590  jlalmanza
#
#         password office_branch  earnings
# 0     z{d>ez%{.@        Nashua     15219
# ...

# %%
path = '/home/muhammadfaizanrafique/data_engineering_bootcamp_2303/tasks/5_data_pipelines/day_4_data_lake/data/output_data/employee_earnings/earnings_date=2023-05-18/employee_earnings.parquet'
df1.to_parquet(path)

# %%
df2 = pd.read_parquet('/home/muhammadfaizanrafique/data_engineering_bootcamp_2303/tasks/5_data_pipelines/day_4_data_lake/data/output_data/employee_earnings/earnings_date=2022-02-12/employee_earnings.parquet')
df2
# Out:
#     emp_id first_name middle_initial last_name                         email  \
# 0   526540  Angelique              K   Goodwin   angelique.goodwin@gmail.com
# 1   859327       Jeni              S   Shaffer        jeni.shaffer@gmail.com
# 2   887387     Donald              T    Farris   donald.farris@bellsouth.net
# 3   779497     Steven              D    Rendon       steven.rendon@gmail.com
# 4   896517     Jenell              L   Almanza      jenell.almanza@yahoo.com
# ..     ...        ...            ...       ...                           ...
# 95  549389   Clemente              M     Gould    clemente.gould@hotmail.com
# 96  466832      Chang              K     Roden         chang.roden@yahoo.com
# 97  203380     Marvin              R    Nickel         marvin.nickel@ibm.com
# 98  915991     Eldora              Y   Tribble  eldora.tribble@earthlink.net
# 99  289172      Azzie              L    Layman    azzie.layman@hotmail.co.uk
#
# ...

# %%
random_numbers = np.random.randint(10000, 100000, size=len(df2))
df1.iloc[:,-1:] = random_numbers
new_earning_col = df1.loc[:,'earnings']
new_earning_col
# Out:
# 0     98808
# 1     14329
# 2     70158
# 3     96355
# 4     54339
#       ...
# 95    29349
# 96    73049
# 97    10889
# 98    94604
# 99    86935
# Name: earnings, Length: 100, dtype: int64

# %%
df2.head()
df2
# Out:
#     emp_id first_name middle_initial last_name                         email  \
# 0   526540  Angelique              K   Goodwin   angelique.goodwin@gmail.com
# 1   859327       Jeni              S   Shaffer        jeni.shaffer@gmail.com
# 2   887387     Donald              T    Farris   donald.farris@bellsouth.net
# 3   779497     Steven              D    Rendon       steven.rendon@gmail.com
# 4   896517     Jenell              L   Almanza      jenell.almanza@yahoo.com
# ..     ...        ...            ...       ...                           ...
# 95  549389   Clemente              M     Gould    clemente.gould@hotmail.com
# 96  466832      Chang              K     Roden         chang.roden@yahoo.com
# 97  203380     Marvin              R    Nickel         marvin.nickel@ibm.com
# 98  915991     Eldora              Y   Tribble  eldora.tribble@earthlink.net
# 99  289172      Azzie              L    Layman    azzie.layman@hotmail.co.uk
#
# ...

# %%
new_path = '/home/muhammadfaizanrafique/data_engineering_bootcamp_2303/tasks/5_data_pipelines/day_4_data_lake/data/output_data/employee_earnings/earnings_date=2023-06-19/employee_earnings.parquet'
df2.to_parquet(new_path)
